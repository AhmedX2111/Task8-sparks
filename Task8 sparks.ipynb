# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import matplotlib.image as mpimg

# %%
df=pd.read_csv(r'C:\Users\Ahmed\Downloads\owid-covid-data.csv')

# %%
df.head(20)
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1       AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2       AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3       AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4       AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 5       AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 6       AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# 7       AFG      Asia  Afghanistan  2020-01-10          NaN        0.0
# 8       AFG      Asia  Afghanistan  2020-01-11          NaN        0.0
# 9       AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
# 10      AFG      Asia  Afghanistan  2020-01-13          NaN        0.0
# 11      AFG      Asia  Afghanistan  2020-01-14          NaN        0.0
# 12      AFG      Asia  Afghanistan  2020-01-15          NaN        0.0
# 13      AFG      Asia  Afghanistan  2020-01-16          NaN        0.0
# 14      AFG      Asia  Afghanistan  2020-01-17          NaN        0.0
# 15      AFG      Asia  Afghanistan  2020-01-18          NaN        0.0
# 16      AFG      Asia  Afghanistan  2020-01-19          NaN        0.0
# 17      AFG      Asia  Afghanistan  2020-01-20          NaN        0.0
# 18      AFG      Asia  Afghanistan  2020-01-21          NaN        0.0
# 19      AFG      Asia  Afghanistan  2020-01-22          NaN        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                  NaN           NaN         0.0                  NaN  ...
# 1                  NaN           NaN         0.0                  NaN  ...
# 2                  NaN           NaN         0.0                  NaN  ...
# 3                  NaN           NaN         0.0                  NaN  ...
# 4                  NaN           NaN         0.0                  NaN  ...
# 5                  0.0           NaN         0.0                  0.0  ...
# 6                  0.0           NaN         0.0                  0.0  ...
# 7                  0.0           NaN         0.0                  0.0  ...
# 8                  0.0           NaN         0.0                  0.0  ...
# 9                  0.0           NaN         0.0                  0.0  ...
# 10                 0.0           NaN         0.0                  0.0  ...
# 11                 0.0           NaN         0.0                  0.0  ...
# 12                 0.0           NaN         0.0                  0.0  ...
# 13                 0.0           NaN         0.0                  0.0  ...
# 14                 0.0           NaN         0.0                  0.0  ...
# 15                 0.0           NaN         0.0                  0.0  ...
# 16                 0.0           NaN         0.0                  0.0  ...
# 17                 0.0           NaN         0.0                  0.0  ...
# 18                 0.0           NaN         0.0                  0.0  ...
# 19                 0.0           NaN         0.0                  0.0  ...
#
#     male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0            NaN                  37.746                         0.5
# 1            NaN                  37.746                         0.5
# 2            NaN                  37.746                         0.5
# 3            NaN                  37.746                         0.5
# 4            NaN                  37.746                         0.5
# 5            NaN                  37.746                         0.5
# 6            NaN                  37.746                         0.5
# 7            NaN                  37.746                         0.5
# 8            NaN                  37.746                         0.5
# 9            NaN                  37.746                         0.5
# 10           NaN                  37.746                         0.5
# 11           NaN                  37.746                         0.5
# 12           NaN                  37.746                         0.5
# 13           NaN                  37.746                         0.5
# 14           NaN                  37.746                         0.5
# 15           NaN                  37.746                         0.5
# 16           NaN                  37.746                         0.5
# 17           NaN                  37.746                         0.5
# 18           NaN                  37.746                         0.5
# 19           NaN                  37.746                         0.5
#
#     life_expectancy  human_development_index  population  \
# 0             64.83                    0.511  41128772.0
# 1             64.83                    0.511  41128772.0
# 2             64.83                    0.511  41128772.0
# 3             64.83                    0.511  41128772.0
# 4             64.83                    0.511  41128772.0
# 5             64.83                    0.511  41128772.0
# 6             64.83                    0.511  41128772.0
# 7             64.83                    0.511  41128772.0
# 8             64.83                    0.511  41128772.0
# 9             64.83                    0.511  41128772.0
# 10            64.83                    0.511  41128772.0
# 11            64.83                    0.511  41128772.0
# 12            64.83                    0.511  41128772.0
# 13            64.83                    0.511  41128772.0
# 14            64.83                    0.511  41128772.0
# 15            64.83                    0.511  41128772.0
# 16            64.83                    0.511  41128772.0
# 17            64.83                    0.511  41128772.0
# 18            64.83                    0.511  41128772.0
# 19            64.83                    0.511  41128772.0
#
#     excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# 5                                    NaN                          NaN
# 6                                    NaN                          NaN
# 7                                    NaN                          NaN
# 8                                    NaN                          NaN
# 9                                    NaN                          NaN
# 10                                   NaN                          NaN
# 11                                   NaN                          NaN
# 12                                   NaN                          NaN
# 13                                   NaN                          NaN
# 14                                   NaN                          NaN
# 15                                   NaN                          NaN
# 16                                   NaN                          NaN
# 17                                   NaN                          NaN
# 18                                   NaN                          NaN
# 19                                   NaN                          NaN
#
#     excess_mortality  excess_mortality_cumulative_per_million
# 0                NaN                                      NaN
# 1                NaN                                      NaN
# 2                NaN                                      NaN
# 3                NaN                                      NaN
# 4                NaN                                      NaN
# 5                NaN                                      NaN
# 6                NaN                                      NaN
# 7                NaN                                      NaN
# 8                NaN                                      NaN
# 9                NaN                                      NaN
# 10               NaN                                      NaN
# 11               NaN                                      NaN
# 12               NaN                                      NaN
# 13               NaN                                      NaN
# 14               NaN                                      NaN
# 15               NaN                                      NaN
# 16               NaN                                      NaN
# 17               NaN                                      NaN
# 18               NaN                                      NaN
# 19               NaN                                      NaN
#
# [20 rows x 67 columns]

# %%
print(df.dtypes.to_string())
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# icu_patients                                  float64
# icu_patients_per_million                      float64
# hosp_patients                                 float64
# hosp_patients_per_million                     float64
# weekly_icu_admissions                         float64
# weekly_icu_admissions_per_million             float64
# weekly_hosp_admissions                        float64
# weekly_hosp_admissions_per_million            float64
# total_tests                                   float64
# new_tests                                     float64
# total_tests_per_thousand                      float64
# new_tests_per_thousand                        float64
# new_tests_smoothed                            float64
# new_tests_smoothed_per_thousand               float64
# positive_rate                                 float64
# tests_per_case                                float64
# tests_units                                    object
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# total_boosters                                float64
# new_vaccinations                              float64
# new_vaccinations_smoothed                     float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# total_boosters_per_hundred                    float64
# new_vaccinations_smoothed_per_million         float64
# new_people_vaccinated_smoothed                float64
# new_people_vaccinated_smoothed_per_hundred    float64
# stringency_index                              float64
# population_density                            float64
# median_age                                    float64
# aged_65_older                                 float64
# aged_70_older                                 float64
# gdp_per_capita                                float64
# extreme_poverty                               float64
# cardiovasc_death_rate                         float64
# diabetes_prevalence                           float64
# female_smokers                                float64
# male_smokers                                  float64
# handwashing_facilities                        float64
# hospital_beds_per_thousand                    float64
# life_expectancy                               float64
# human_development_index                       float64
# population                                    float64
# excess_mortality_cumulative_absolute          float64
# excess_mortality_cumulative                   float64
# excess_mortality                              float64
# excess_mortality_cumulative_per_million       float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304585 entries, 0 to 304584
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    304585 non-null  object
#  1   continent                                   290085 non-null  object
#  2   location                                    304585 non-null  object
#  3   date                                        304585 non-null  object
#  4   total_cases                                 268489 non-null  float64
#  5   new_cases                                   295743 non-null  float64
#  6   new_cases_smoothed                          294479 non-null  float64
#  7   total_deaths                                247931 non-null  float64
#  8   new_deaths                                  295839 non-null  float64
#  9   new_deaths_smoothed                         294609 non-null  float64
#  10  total_cases_per_million                     268489 non-null  float64
#  11  new_cases_per_million                       295743 non-null  float64
#  12  new_cases_smoothed_per_million              294479 non-null  float64
#  13  total_deaths_per_million                    247931 non-null  float64
#  14  new_deaths_per_million                      295839 non-null  float64
#  15  new_deaths_smoothed_per_million             294609 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                35011 non-null   float64
#  18  icu_patients_per_million                    35011 non-null   float64
#  19  hosp_patients                               35387 non-null   float64
#  20  hosp_patients_per_million                   35387 non-null   float64
#  21  weekly_icu_admissions                       9282 non-null    float64
#  22  weekly_icu_admissions_per_million           9282 non-null    float64
#  23  weekly_hosp_admissions                      21566 non-null   float64
#  24  weekly_hosp_admissions_per_million          21566 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          74105 non-null   float64
#  35  people_vaccinated                           70960 non-null   float64
#  36  people_fully_vaccinated                     68709 non-null   float64
#  37  total_boosters                              42811 non-null   float64
#  38  new_vaccinations                            60990 non-null   float64
#  39  new_vaccinations_smoothed                   164875 non-null  float64
#  40  total_vaccinations_per_hundred              74105 non-null   float64
#  41  people_vaccinated_per_hundred               70960 non-null   float64
#  42  people_fully_vaccinated_per_hundred         68709 non-null   float64
#  43  total_boosters_per_hundred                  42811 non-null   float64
#  44  new_vaccinations_smoothed_per_million       164875 non-null  float64
#  45  new_people_vaccinated_smoothed              164960 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  164960 non-null  float64
#  47  stringency_index                            193194 non-null  float64
#  48  population_density                          258424 non-null  float64
#  49  median_age                                  240373 non-null  float64
#  50  aged_65_older                               231958 non-null  float64
#  51  aged_70_older                               237961 non-null  float64
#  52  gdp_per_capita                              235558 non-null  float64
#  53  extreme_poverty                             151723 non-null  float64
#  54  cardiovasc_death_rate                       235981 non-null  float64
#  55  diabetes_prevalence                         248005 non-null  float64
#  56  female_smokers                              177036 non-null  float64
#  57  male_smokers                                174626 non-null  float64
#  58  handwashing_facilities                      115534 non-null  float64
#  59  hospital_beds_per_thousand                  208319 non-null  float64
#  60  life_expectancy                             280072 non-null  float64
#  61  human_development_index                     228746 non-null  float64
#  62  population                                  304585 non-null  float64
#  63  excess_mortality_cumulative_absolute        10669 non-null   float64
#  64  excess_mortality_cumulative                 10669 non-null   float64
#  65  excess_mortality                            10669 non-null   float64
#  66  excess_mortality_cumulative_per_million     10669 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 155.7+ MB

# %%
df.count()
# Out:
# iso_code                                   304585
# continent                                  290085
# location                                   304585
# date                                       304585
# total_cases                                268489
#                                             ...
# population                                 304585
# excess_mortality_cumulative_absolute        10669
# excess_mortality_cumulative                 10669
# excess_mortality                            10669
# excess_mortality_cumulative_per_million     10669
# Length: 67, dtype: int64

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.684890e+05  2.957430e+05        2.944790e+05  2.479310e+05
# mean   5.576081e+06  1.094674e+04        1.099127e+04  7.952890e+04
# std    3.493830e+07  1.041787e+05        1.013988e+05  4.115333e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    6.329000e+03  0.000000e+00        1.143000e+00  1.190000e+02
# 50%    6.055700e+04  1.800000e+01        3.957100e+01  1.202000e+03
# 75%    6.208530e+05  5.470000e+02        6.492860e+02  1.041800e+04
# max    7.637394e+08  7.460688e+06        6.410718e+06  6.908541e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  295839.000000        294609.000000            268489.000000
# mean       97.627476            98.018766             85145.420991
# std       607.167291           597.863069            135418.021397
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              1931.610000
# 50%         0.000000             0.286000             19547.705000
# 75%         6.000000             6.857000            103859.873000
# max     20010.000000         14675.571000            733146.058000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          295743.000000                   294479.000000
# mean              164.986181                      165.646951
# std              1137.932219                      640.963593
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.281000
# 50%                 2.677000                       11.251000
# 75%                71.934500                      107.333000
# max            228872.025000                    37241.781000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             247931.000000  ...  174626.000000           115534.000000
# mean                 798.463973  ...      32.912573               50.794928
# std                 1043.865749  ...      13.571348               31.955344
# min                    0.000000  ...       7.700000                1.188000
# 25%                   47.988000  ...      22.600000               20.859000
# 50%                  329.361000  ...      33.100000               49.839000
# 75%                 1224.039500  ...      41.300000               83.241000
# max                 6460.900000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               208319.000000    280072.000000            228746.000000
# mean                     3.098352        73.722238                 0.722576
# std                      2.549145         7.396914                 0.149001
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.590000                 0.602000
# 50%                      2.500000        75.050000                 0.740000
# 75%                      4.200000        79.460000                 0.829000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  3.045850e+05                          1.066900e+04
# mean   1.284199e+08                          4.739668e+04
# std    6.606690e+08                          1.384241e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    4.490020e+05                          2.780000e+01
# 50%    5.882259e+06                          4.530999e+03
# 75%    2.830170e+07                          3.159700e+04
# max    7.975105e+09                          1.282260e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                 10669.000000      10669.000000
# mean                      9.538903         12.633550
# std                      12.914011         26.344219
# min                     -44.230000        -95.920000
# 25%                       0.560000         -1.200000
# 50%                       7.750000          6.490000
# 75%                      15.360000         18.070000
# max                      76.550000        377.300000
#
#        excess_mortality_cumulative_per_million
# count                             10669.000000
# mean                               1477.149682
# std                                1840.907839
# min                               -1984.281600
# 25%                                  24.645111
# 50%                                 900.418500
# 75%                                2399.257000
# max                               10291.122000
#
# [8 rows x 62 columns]

# %%
print(df.isnull().sum().to_string())
# Out:
# iso_code                                           0
# continent                                      14500
# location                                           0
# date                                               0
# total_cases                                    36096
# new_cases                                       8842
# new_cases_smoothed                             10106
# total_deaths                                   56654
# new_deaths                                      8746
# new_deaths_smoothed                             9976
# total_cases_per_million                        36096
# new_cases_per_million                           8842
# new_cases_smoothed_per_million                 10106
# total_deaths_per_million                       56654
# new_deaths_per_million                          8746
# new_deaths_smoothed_per_million                 9976
# reproduction_rate                             119768
# icu_patients                                  269574
# icu_patients_per_million                      269574
# hosp_patients                                 269198
# hosp_patients_per_million                     269198
# weekly_icu_admissions                         295303
# weekly_icu_admissions_per_million             295303
# weekly_hosp_admissions                        283019
# weekly_hosp_admissions_per_million            283019
# total_tests                                   225198
# new_tests                                     229182
# total_tests_per_thousand                      225198
# new_tests_per_thousand                        229182
# new_tests_smoothed                            200620
# new_tests_smoothed_per_thousand               200620
# positive_rate                                 208658
# tests_per_case                                210237
# tests_units                                   197797
# total_vaccinations                            230480
# people_vaccinated                             233625
# people_fully_vaccinated                       235876
# total_boosters                                261774
# new_vaccinations                              243595
# new_vaccinations_smoothed                     139710
# total_vaccinations_per_hundred                230480
# people_vaccinated_per_hundred                 233625
# people_fully_vaccinated_per_hundred           235876
# total_boosters_per_hundred                    261774
# new_vaccinations_smoothed_per_million         139710
# new_people_vaccinated_smoothed                139625
# new_people_vaccinated_smoothed_per_hundred    139625
# stringency_index                              111391
# population_density                             46161
# median_age                                     64212
# aged_65_older                                  72627
# aged_70_older                                  66624
# gdp_per_capita                                 69027
# extreme_poverty                               152862
# cardiovasc_death_rate                          68604
# diabetes_prevalence                            56580
# female_smokers                                127549
# male_smokers                                  129959
# handwashing_facilities                        189051
# hospital_beds_per_thousand                     96266
# life_expectancy                                24513
# human_development_index                        75839
# population                                         0
# excess_mortality_cumulative_absolute          293916
# excess_mortality_cumulative                   293916
# excess_mortality                              293916
# excess_mortality_cumulative_per_million       293916

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df2 = df[['continent','location','date','total_cases','new_cases','total_deaths','new_deaths','total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_vaccinations','people_fully_vaccinated','population','hospital_beds_per_thousand','median_age','aged_65_older','aged_70_older','life_expectancy']].copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304585 entries, 0 to 304584
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   continent                   290085 non-null  object
#  1   location                    304585 non-null  object
#  2   date                        304585 non-null  object
#  3   total_cases                 268489 non-null  float64
#  4   new_cases                   295743 non-null  float64
#  5   total_deaths                247931 non-null  float64
#  6   new_deaths                  295839 non-null  float64
#  7   total_cases_per_million     268489 non-null  float64
#  8   new_cases_per_million       295743 non-null  float64
#  9   total_deaths_per_million    247931 non-null  float64
#  10  new_deaths_per_million      295839 non-null  float64
#  11  total_tests                 79387 non-null   float64
#  12  new_tests                   75403 non-null   float64
#  13  total_vaccinations          74105 non-null   float64
#  14  people_fully_vaccinated     68709 non-null   float64
#  15  population                  304585 non-null  float64
#  16  hospital_beds_per_thousand  208319 non-null  float64
#  17  median_age                  240373 non-null  float64
#  18  aged_65_older               231958 non-null  float64
#  19  aged_70_older               237961 non-null  float64
#  20  life_expectancy             280072 non-null  float64
# dtypes: float64(18), object(3)
# memory usage: 48.8+ MB

# %%
df2.describe()
# Out:
#         total_cases     new_cases  total_deaths     new_deaths  \
# count  2.684890e+05  2.957430e+05  2.479310e+05  295839.000000
# mean   5.576081e+06  1.094674e+04  7.952890e+04      97.627476
# std    3.493830e+07  1.041787e+05  4.115333e+05     607.167291
# min    1.000000e+00  0.000000e+00  1.000000e+00       0.000000
# 25%    6.329000e+03  0.000000e+00  1.190000e+02       0.000000
# 50%    6.055700e+04  1.800000e+01  1.202000e+03       0.000000
# 75%    6.208530e+05  5.470000e+02  1.041800e+04       6.000000
# max    7.637394e+08  7.460688e+06  6.908541e+06   20010.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count            268489.000000          295743.000000
# mean              85145.420991             164.986181
# std              135418.021397            1137.932219
# min                   0.000000               0.000000
# 25%                1931.610000               0.000000
# 50%               19547.705000               2.677000
# 75%              103859.873000              71.934500
# max              733146.058000          228872.025000
#
#        total_deaths_per_million  new_deaths_per_million   total_tests  \
# count             247931.000000           295839.000000  7.938700e+04
# mean                 798.463973                1.036021  2.110457e+07
# std                 1043.865749                4.726460  8.409869e+07
# min                    0.000000                0.000000  0.000000e+00
# 25%                   47.988000                0.000000  3.646540e+05
# 50%                  329.361000                0.000000  2.067330e+06
# 75%                 1224.039500                0.450000  1.024845e+07
# max                 6460.900000              603.656000  9.214000e+09
#
#           new_tests  total_vaccinations  people_fully_vaccinated  \
# count  7.540300e+04        7.410500e+04             6.870900e+04
# mean   6.728541e+04        3.683930e+08             1.458993e+08
# std    2.477340e+05        1.400913e+09             5.653901e+08
# min    1.000000e+00        0.000000e+00             1.000000e+00
# 25%    2.244000e+03        1.446090e+06             7.315220e+05
# 50%    8.783000e+03        1.097344e+07             4.740226e+06
# 75%    3.722900e+04        8.016569e+07             3.175825e+07
# max    3.585563e+07        1.337369e+10             5.129429e+09
#
#          population  hospital_beds_per_thousand     median_age  aged_65_older  \
# count  3.045850e+05               208319.000000  240373.000000  231958.000000
# mean   1.284199e+08                    3.098352      30.518067       8.705186
# std    6.606690e+08                    2.549145       9.084941       6.095300
# min    4.700000e+01                    0.100000      15.100000       1.144000
# 25%    4.490020e+05                    1.300000      22.200000       3.526000
# 50%    5.882259e+06                    2.500000      29.700000       6.378000
# 75%    2.830170e+07                    4.200000      38.700000      13.928000
# max    7.975105e+09                   13.800000      48.200000      27.049000
#
#        aged_70_older  life_expectancy
# count  237961.000000    280072.000000
# mean        5.502635        73.722238
# std         4.136564         7.396914
# min         0.526000        53.280000
# 25%         2.085000        69.590000
# 50%         3.871000        75.050000
# 75%         8.643000        79.460000
# max        18.493000        86.750000

# %%
df2.isnull().sum()
# Out:
# continent                      14500
# location                           0
# date                               0
# total_cases                    36096
# new_cases                       8842
# total_deaths                   56654
# new_deaths                      8746
# total_cases_per_million        36096
# new_cases_per_million           8842
# total_deaths_per_million       56654
# new_deaths_per_million          8746
# total_tests                   225198
# new_tests                     229182
# total_vaccinations            230480
# people_fully_vaccinated       235876
# population                         0
# hospital_beds_per_thousand     96266
# median_age                     64212
# aged_65_older                  72627
# aged_70_older                  66624
# life_expectancy                24513
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# continent                     0
# location                      0
# date                          0
# total_cases                   0
# new_cases                     0
# total_deaths                  0
# new_deaths                    0
# total_cases_per_million       0
# new_cases_per_million         0
# total_deaths_per_million      0
# new_deaths_per_million        0
# total_tests                   0
# new_tests                     0
# total_vaccinations            0
# people_fully_vaccinated       0
# population                    0
# hospital_beds_per_thousand    0
# median_age                    0
# aged_65_older                 0
# aged_70_older                 0
# life_expectancy               0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23144 entries, 2807 to 304249
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   continent                   23144 non-null  object
#  1   location                    23144 non-null  object
#  2   date                        23144 non-null  object
#  3   total_cases                 23144 non-null  float64
#  4   new_cases                   23144 non-null  float64
#  5   total_deaths                23144 non-null  float64
#  6   new_deaths                  23144 non-null  float64
#  7   total_cases_per_million     23144 non-null  float64
#  8   new_cases_per_million       23144 non-null  float64
#  9   total_deaths_per_million    23144 non-null  float64
#  10  new_deaths_per_million      23144 non-null  float64
#  11  total_tests                 23144 non-null  float64
#  12  new_tests                   23144 non-null  float64
#  13  total_vaccinations          23144 non-null  float64
#  14  people_fully_vaccinated     23144 non-null  float64
#  15  population                  23144 non-null  float64
#  16  hospital_beds_per_thousand  23144 non-null  float64
#  17  median_age                  23144 non-null  float64
#  18  aged_65_older               23144 non-null  float64
#  19  aged_70_older               23144 non-null  float64
#  20  life_expectancy             23144 non-null  float64
# dtypes: float64(18), object(3)
# memory usage: 3.9+ MB

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23144 entries, 2807 to 304249
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   continent                   23144 non-null  object
#  1   location                    23144 non-null  object
#  2   date                        23144 non-null  object
#  3   total_cases                 23144 non-null  float64
#  4   new_cases                   23144 non-null  float64
#  5   total_deaths                23144 non-null  float64
#  6   new_deaths                  23144 non-null  float64
#  7   total_cases_per_million     23144 non-null  float64
#  8   new_cases_per_million       23144 non-null  float64
#  9   total_deaths_per_million    23144 non-null  float64
#  10  new_deaths_per_million      23144 non-null  float64
#  11  total_tests                 23144 non-null  float64
#  12  new_tests                   23144 non-null  float64
#  13  total_vaccinations          23144 non-null  float64
#  14  people_fully_vaccinated     23144 non-null  float64
#  15  population                  23144 non-null  float64
#  16  hospital_beds_per_thousand  23144 non-null  float64
#  17  median_age                  23144 non-null  float64
#  18  aged_65_older               23144 non-null  float64
#  19  aged_70_older               23144 non-null  float64
#  20  life_expectancy             23144 non-null  float64
# dtypes: float64(18), object(3)
# memory usage: 3.9+ MB

# %%
sns.boxplot(df2['total_cases'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_cases'>

# %%
sns.boxplot(df2['new_cases'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='new_cases'>

# %%
sns.boxplot(df2['total_deaths'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_deaths'>

# %%
sns.boxplot(df2['new_deaths'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='new_deaths'>

# %%
q1=df2.total_cases.quantile(0.25)
q3=df2.total_cases.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['total_cases']<(q1-1.5*iqr)) | (df2['total_cases']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (20867, 21)

# %%
q1=df2.new_cases.quantile(0.25)
q3=df2.new_cases.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['new_cases']<(q1-1.5*iqr)) | (df2['new_cases']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (18371, 21)

# %%
q1=df2.total_deaths.quantile(0.25)
q3=df2.total_deaths.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['total_deaths']<(q1-1.5*iqr)) | (df2['total_deaths']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (16544, 21)

# %%
q1=df2.new_deaths.quantile(0.25)
q3=df2.new_deaths.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['new_deaths']<(q1-1.5*iqr)) | (df2['new_deaths']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (14910, 21)

# %%
q1=df2.total_cases_per_million.quantile(0.25)
q3=df2.total_cases_per_million.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['total_cases_per_million']<(q1-1.5*iqr)) | (df2['total_cases_per_million']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (13440, 21)

# %%
q1=df2.total_deaths_per_million.quantile(0.25)
q3=df2.total_deaths_per_million.quantile(0.75)
iqr=q3-q1
df2=df2[~((df2['total_deaths_per_million']<(q1-1.5*iqr)) | (df2['total_deaths_per_million']>(q3+1.5*iqr)))]
df2.shape
# Out:
# (13401, 21)

# %%
df2.shape
# Out:
# (13401, 21)

# %%
df2.corr()
# Out:
#                             total_cases  new_cases  total_deaths  new_deaths  \
# total_cases                    1.000000   0.394428      0.745156    0.299097
# new_cases                      0.394428   1.000000      0.306047    0.468033
# total_deaths                   0.745156   0.306047      1.000000    0.326066
# new_deaths                     0.299097   0.468033      0.326066    1.000000
# total_cases_per_million        0.275934   0.154704      0.105977   -0.057634
# new_cases_per_million         -0.079989   0.470747     -0.151696    0.097719
# total_deaths_per_million       0.157458   0.046222      0.410211    0.062672
# new_deaths_per_million        -0.161534   0.109635     -0.161709    0.430346
# total_tests                    0.585261   0.235307      0.316327    0.097160
# new_tests                      0.270583   0.248516      0.122989    0.132127
# total_vaccinations             0.582729   0.236039      0.439502    0.109172
# people_fully_vaccinated        0.530976   0.209060      0.404047    0.088558
# population                     0.369706   0.183989      0.359164    0.216881
# hospital_beds_per_thousand    -0.042356   0.014661     -0.088586   -0.003027
# median_age                    -0.000228   0.067512     -0.089511   -0.013655
# aged_65_older                 -0.017668   0.050652     -0.061416    0.010213
# aged_70_older                 -0.028686   0.049753     -0.064477    0.017950
# life_expectancy                0.110427   0.130684     -0.016829   -0.027248
#
#                             total_cases_per_million  new_cases_per_million  \
# total_cases                                0.275934              -0.079989
# new_cases                                  0.154704               0.470747
# total_deaths                               0.105977              -0.151696
# new_deaths                                -0.057634               0.097719
# total_cases_per_million                    1.000000               0.461519
# new_cases_per_million                      0.461519               1.000000
# total_deaths_per_million                   0.659655               0.203841
# new_deaths_per_million                     0.239281               0.433368
# total_tests                                0.126191              -0.100671
# new_tests                                  0.022609              -0.041117
# total_vaccinations                        -0.124043              -0.148296
# people_fully_vaccinated                   -0.129531              -0.141784
# population                                -0.353328              -0.212699
# hospital_beds_per_thousand                 0.072427               0.067119
# median_age                                 0.319829               0.189610
# aged_65_older                              0.287063               0.188851
# aged_70_older                              0.296393               0.203252
# life_expectancy                            0.251106               0.097887
#
#                             total_deaths_per_million  new_deaths_per_million  \
# total_cases                                 0.157458               -0.161534
# new_cases                                   0.046222                0.109635
# total_deaths                                0.410211               -0.161709
# new_deaths                                  0.062672                0.430346
# total_cases_per_million                     0.659655                0.239281
# new_cases_per_million                       0.203841                0.433368
# total_deaths_per_million                    1.000000                0.270361
# new_deaths_per_million                      0.270361                1.000000
# total_tests                                -0.096527               -0.203432
# new_tests                                  -0.124140               -0.125907
# total_vaccinations                         -0.172924               -0.213175
# people_fully_vaccinated                    -0.168584               -0.202834
# population                                 -0.331337               -0.240458
# hospital_beds_per_thousand                  0.074251                0.072527
# median_age                                  0.260170                0.180847
# aged_65_older                               0.292474                0.178565
# aged_70_older                               0.310790                0.203023
# life_expectancy                             0.075445               -0.045458
#
#                             total_tests  new_tests  total_vaccinations  \
# total_cases                    0.585261   0.270583            0.582729
# new_cases                      0.235307   0.248516            0.236039
# total_deaths                   0.316327   0.122989            0.439502
# new_deaths                     0.097160   0.132127            0.109172
# total_cases_per_million        0.126191   0.022609           -0.124043
# new_cases_per_million         -0.100671  -0.041117           -0.148296
# total_deaths_per_million      -0.096527  -0.124140           -0.172924
# new_deaths_per_million        -0.203432  -0.125907           -0.213175
# total_tests                    1.000000   0.766892            0.440476
# new_tests                      0.766892   1.000000            0.225609
# total_vaccinations             0.440476   0.225609            1.000000
# people_fully_vaccinated        0.408260   0.207700            0.991621
# population                     0.233356   0.159981            0.691821
# hospital_beds_per_thousand     0.056081   0.149886            0.169541
# median_age                     0.107400   0.144516            0.035387
# aged_65_older                 -0.050773  -0.007057            0.001607
# aged_70_older                 -0.062363  -0.010808           -0.007689
# life_expectancy                0.241787   0.247847            0.095843
#
#                             people_fully_vaccinated  population  \
# total_cases                                0.530976    0.369706
# new_cases                                  0.209060    0.183989
# total_deaths                               0.404047    0.359164
# new_deaths                                 0.088558    0.216881
# total_cases_per_million                   -0.129531   -0.353328
# new_cases_per_million                     -0.141784   -0.212699
# total_deaths_per_million                  -0.168584   -0.331337
# new_deaths_per_million                    -0.202834   -0.240458
# total_tests                                0.408260    0.233356
# new_tests                                  0.207700    0.159981
# total_vaccinations                         0.991621    0.691821
# people_fully_vaccinated                    1.000000    0.667422
# population                                 0.667422    1.000000
# hospital_beds_per_thousand                 0.189378    0.128163
# median_age                                 0.045813   -0.103801
# aged_65_older                              0.021233   -0.103233
# aged_70_older                              0.013646   -0.104984
# life_expectancy                            0.095506   -0.085119
#
#                             hospital_beds_per_thousand  median_age  \
# total_cases                                  -0.042356   -0.000228
# new_cases                                     0.014661    0.067512
# total_deaths                                 -0.088586   -0.089511
# new_deaths                                   -0.003027   -0.013655
# total_cases_per_million                       0.072427    0.319829
# new_cases_per_million                         0.067119    0.189610
# total_deaths_per_million                      0.074251    0.260170
# new_deaths_per_million                        0.072527    0.180847
# total_tests                                   0.056081    0.107400
# new_tests                                     0.149886    0.144516
# total_vaccinations                            0.169541    0.035387
# people_fully_vaccinated                       0.189378    0.045813
# population                                    0.128163   -0.103801
# hospital_beds_per_thousand                    1.000000    0.672784
# median_age                                    0.672784    1.000000
# aged_65_older                                 0.637457    0.903261
# aged_70_older                                 0.636338    0.888786
# life_expectancy                               0.388835    0.735312
#
#                             aged_65_older  aged_70_older  life_expectancy
# total_cases                     -0.017668      -0.028686         0.110427
# new_cases                        0.050652       0.049753         0.130684
# total_deaths                    -0.061416      -0.064477        -0.016829
# new_deaths                       0.010213       0.017950        -0.027248
# total_cases_per_million          0.287063       0.296393         0.251106
# new_cases_per_million            0.188851       0.203252         0.097887
# total_deaths_per_million         0.292474       0.310790         0.075445
# new_deaths_per_million           0.178565       0.203023        -0.045458
# total_tests                     -0.050773      -0.062363         0.241787
# new_tests                       -0.007057      -0.010808         0.247847
# total_vaccinations               0.001607      -0.007689         0.095843
# people_fully_vaccinated          0.021233       0.013646         0.095506
# population                      -0.103233      -0.104984        -0.085119
# hospital_beds_per_thousand       0.637457       0.636338         0.388835
# median_age                       0.903261       0.888786         0.735312
# aged_65_older                    1.000000       0.990975         0.669943
# aged_70_older                    0.990975       1.000000         0.630312
# life_expectancy                  0.669943       0.630312         1.000000

# %%
sns.regplot(df2['total_cases'],df2['total_deaths'],fit_reg=False)
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_cases', ylabel='total_deaths'>

# %%
sns.regplot(df2['aged_70_older'],df2['aged_65_older'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='aged_70_older', ylabel='aged_65_older'>

# %%
sns.regplot(df2['total_deaths'],df2['aged_65_older'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='total_deaths', ylabel='aged_65_older'>

# %%
sns.regplot(df2['total_cases'],df2['aged_65_older'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='aged_65_older'>

# %%
df2.to_csv('COVID_19.csv',index=False)

# %%
img = mpimg.imread('C:/Users/Ahmed/OneDrive/Pictures/Screenshots/Map4.png')
plt.imshow(img)
plt.axis('off')
plt.show()
